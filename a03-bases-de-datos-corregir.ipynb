# %%
# !service mysql status
# Out:
# mysql: unrecognized service

# %%
# !service mysql status
# Out:
# mysql: unrecognized service

# %% [markdown]
# # Instalaciones e importaciones

# %%
# Instalación de MySQL Connector Python y Pandas
# !pip install mysql-connector-python
# !pip install pandas

# %%
# Importamos Pandas
import mysql.connector
import pandas as pd

# %% [markdown]
# Prueba importando desde un csv

# %%
# URL del archivo CSV en GitHub
url = 'https://raw.githubusercontent.com/liazamudio/datasets/main/titanic-dataset.csv'

# Leer el archivo CSV desde la URL
df_titanic = pd.read_csv(url)

# Imprimir las primeras filas del DataFrame para verificar
df_titanic.head()

# %% [markdown]
# # Bases de datos

# %%
# !service mysql status
# Out:
# mysql: unrecognized service

# %%
# !service mysql start
# Out:
# mysql: unrecognized service

# %%
# Conexión a la base de datos de MySQL
cnx = mysql.connector.connect(
   host="localhost",
   port=3306,
   user="root",
   password='2023*DaSci',
   database='titanic-passengers'
)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/mysql/connector/connection_cext.py in _open_connection(self)
#     322         try:
# --> 323             self._cmysql.connect(**cnx_kwargs)
#     324             self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Can't connect to MySQL server on 'localhost:3306' (99)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-3-7948143d222a> in <cell line: 2>()
#       1 # Conexión a la base de datos de MySQL
# ----> 2 cnx = mysql.connector.connect(
#       3    host="localhost",
#       4    port=3306,
#       5    user="root",
#
# /usr/local/lib/python3.10/dist-packages/mysql/connector/pooling.py in connect(*args, **kwargs)
#     320
# ...
